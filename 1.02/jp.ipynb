# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

font = {'font': 'dejavu',
        'family': 'serif',
        'weight': 'normal',
        'size': 16,
        }
plt.rcParams["mathtext.fontset"] = 'dejavuserif'

data1 = pd.read_csv('data_1.csv', delimiter=';') #1 task
data2 = pd.read_csv('data_2.csv', delimiter=';') #2 task
sina = []
for index, rows in data1.iterrows():
    sina.append(float(rows['x2']) - float(rows['x1']))
n=range(len(z))
data1.insert(8, column='y', value=y)
data1.insert(9, column='z', value=z)


z_mean = sum(z)/len(z)
y_mean = sum(y)/len(y)
a = sum(z[i]*y[i] for i in n )/sum(z[i]**2 for i in n) #method of minimal squares
yn = list(map((lambda x: x*a), z)) #method of minimal squares

#plotting
plt.grid()
plt.ylabel("x, cm")
plt.xlabel("t, c")
plt.scatter(z, y, c='red', s = 1)
plt.plot(z, yn, color='blue', )
plt.show()

sko_a = (sum((y[i]-a*z[i])**2 for i in n) 
       / 
       ((len(z)-1) * sum(z[i]**2 for i in n)))**0.5

absolute_inac = 2*sko_a #абсолютная погрешность
relative_inac = absolute_inac/a #относительная погрешность
